# %% [markdown]
# <a href="https://colab.research.google.com/github/GayatriPisya/python_experiments/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment-2 Pandas

# %%
pip install pandas

# %%
import pandas as pd

# %%
Data ={
     'Name':['Sireesha Modi ','Kishore Babu','Gayatri Pisya'],
     'Age': [21,19,20]
     }

# %%
df = pd.DataFrame(Data)
print(df)
# Out:
#              Name  Age
# 0  Sireesha Modi    21
# 1    Kishore Babu   19
# 2   Gayatri Pisya   20

# %%
csv_file ="iris_dataset.csv"
df.to_csv(csv_file, index=False)

# %%
df = pd.read_csv(csv_file)

# %%
excel_file ="Project-Management-Sample-Data.xlsx"
df.to_excel(excel_file)

# %%
df = pd.read_excel(excel_file)

# %%
print(df.head())
# Out:
#    Unnamed: 0            Name  Age
# 0           0  Sireesha Modi    21
# 1           1    Kishore Babu   19
# 2           2   Gayatri Pisya   20

# %%
print(df.describe())
# Out:
#        Unnamed: 0   Age
# count         3.0   3.0
# mean          1.0  20.0
# std           1.0   1.0
# min           0.0  19.0
# 25%           0.5  19.5
# 50%           1.0  20.0
# 75%           1.5  20.5
# max           2.0  21.0

# %%
ages = df['Age']
print(ages)
# Out:
# 0    21
# 1    19
# 2    20
# Name: Age, dtype: int64

# %%
People = df[df['Age'] < 20]
print(People)
# Out:
#    Unnamed: 0          Name  Age
# 1           1  Kishore Babu   19

# %%
sorted_df = df.sort_values(by='Age')
print(sorted_df)
# Out:
#    Unnamed: 0            Name  Age
# 1           1    Kishore Babu   19
# 2           2   Gayatri Pisya   20
# 0           0  Sireesha Modi    21

# %%
df['Gender'] = ['Female', 'Male', 'Female']
print(df)
# Out:
#    Unnamed: 0      Name  Age  Gender
# 0           0  Sireesha   21  Female
# 1           1   Kishore   19    Male
# 2           2   Gayatri   20  Female

# %%
df.rename(columns={'Name': 'Full Name', 'Age': 'Years Old'}, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna()
# Out:
#    Unnamed: 0       Full Name  Years Old
# 0           0  Sireesha Modi          21
# 1           1    Kishore Babu         19
# 2           2   Gayatri Pisya         20
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Years Old'].plot(kind='hist', bins=20, title='Years Old')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Full Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['Years Old'].plot(kind='hist', bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
